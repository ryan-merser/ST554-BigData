# %%
#%%writefile ~/SparkDataCheck.py
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from functools import reduce
from pyspark.sql.types import *
import pandas as pd
# Out:
# Overwriting /home/jupyter-ramerser@ncsu.edu/SparkDataCheck.py

# %%
import SparkDataCheck

# %%
import importlib
importlib.reload(SparkDataCheck)
# Out:
# <module 'SparkDataCheck' from '/home/jupyter-ramerser@ncsu.edu/SparkDataCheck.py'>

# %%
air_df = pd.read_csv("https://www4.stat.ncsu.edu/online/datasets/air.csv")
air_df.head()
# Out:
#    Unnamed: 0       Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0           0  3/10/2004  18:00:00     2.6         1360       150      11.9
# 1           1  3/10/2004  19:00:00     2.0         1292       112       9.4
# 2           2  3/10/2004  20:00:00     2.2         1402        88       9.0
# 3           3  3/10/2004  21:00:00     2.2         1376        80       9.2
# 4           4  3/10/2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888
